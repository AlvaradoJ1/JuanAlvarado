# %% [markdown]
# 1. Realizar un análisis exploratorio de los datos para identificar relaciones entre variables, valores atípicos, tendencias, etc.

# %%
# Cargar Las Librerias necesrias
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 

# Librerías de para implementar modelos de ciencia de datos
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, auc

# %%
#cargar archivo
Datos = pd.read_csv('./Vino.csv')

# %%
#lectura de datos para realizar el 
Datos.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
Datos.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#Identificación de Datos Faltantes y Atípicos de fixed acidity
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['fixed acidity'])
plt.title('Identificación de Datos Faltantes y Atípicos de fixed acidity', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de fixed acidity')

# %%
#Identificación de Datos Faltantes y Atípicos de volatile acidity
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['volatile acidity'])
plt.title('Identificación de Datos Faltantes y Atípicos de volatile acidity', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de volatile acidity')

# %%
#Identificación de Datos Faltantes y Atípicos de citric acid
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['citric acid'])
plt.title('Identificación de Datos Faltantes y Atípicos de citric acid', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de citric acid')

# %%
#Identificación de Datos Faltantes y Atípicos de residual sugar
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['residual sugar'])
plt.title('Identificación de Datos Faltantes y Atípicos de residual sugar', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de residual sugar')

# %%
#Identificación de Datos Faltantes y Atípicos de chlorides
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['chlorides'])
plt.title('Identificación de Datos Faltantes y Atípicos de chlorides', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de chlorides')

# %%
#Identificación de Datos Faltantes y Atípicos de free sulfur dioxide
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['free sulfur dioxide'])
plt.title('Identificación de Datos Faltantes y Atípicos de free sulfur dioxide', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de free sulfur dioxide')

# %%
#Identificación de Datos Faltantes y Atípicos de total sulfur dioxide
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['total sulfur dioxide'])
plt.title('Identificación de Datos Faltantes y Atípicos de total sulfur dioxide', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de total sulfur dioxide')

# %%
#Identificación de Datos Faltantes y Atípicos de density
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['density'])
plt.title('Identificación de Datos Faltantes y Atípicos ', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de density')

# %%
#Identificación de Datos Faltantes y Atípicos de pH
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['pH'])
plt.title('Identificación de Datos Faltantes y Atípicos de pH', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de pH')

# %%
#Identificación de Datos Faltantes y Atípicos de sulphates
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['sulphates'])
plt.title('Identificación de Datos Faltantes y Atípicos de sulphates', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de sulphates')

# %%
#Identificación de Datos Faltantes y Atípicos de alcohol
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['alcohol'])
plt.title('Identificación de Datos Faltantes y Atípicos de alcohol', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de alcohol')

# %%
#Identificación de Datos Faltantes y Atípicos de quality
plt.figure(figsize=(6, 3))
sns.boxplot (x=Datos ['quality'])
plt.title('Identificación de Datos Faltantes y Atípicos de quality', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atípicos de quality')

# %%
#Conteo de Datos Atípicos
nivel_minimo=4
nivel_maximo=15
Total_Atipicos=((Datos['fixed acidity']<nivel_minimo)|(Datos['fixed acidity']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 5

# %%
# Filtra Datos Atípicos

Datos=Datos[(Datos['fixed acidity']<nivel_maximo)&(Datos['fixed acidity']>nivel_minimo)]

# %%
# Validar si se removieron los datos atípicos

Total_Atipicos=((Datos['fixed acidity']<nivel_minimo)|(Datos['fixed acidity']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 0

# %%
#Conteo de Datos Atípicos
nivel_minimo=0
nivel_maximo=1.4
Total_Atipicos=((Datos['volatile acidity']<nivel_minimo)|(Datos['volatile acidity']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 1

# %%
# Filtra Datos Atípicos

Datos=Datos[(Datos['volatile acidity']<nivel_maximo)&(Datos['volatile acidity']>nivel_minimo)]

# %%
# Validar si se removieron los datos atípicos

Total_Atipicos=((Datos['volatile acidity']<nivel_minimo)|(Datos['volatile acidity']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 0

# %%
#Conteo de Datos Atípicos
nivel_minimo=0
nivel_maximo=12
Total_Atipicos=((Datos['residual sugar']<nivel_minimo)|(Datos['residual sugar']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 8

# %%
# Filtra Datos Atípicos

Datos=Datos[(Datos['residual sugar']<nivel_maximo)&(Datos['residual sugar']>nivel_minimo)]

# %%
# Validar si se removieron los datos atípicos

Total_Atipicos=((Datos['residual sugar']<nivel_minimo)|(Datos['residual sugar']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 0

# %%
#Conteo de Datos Atípicos
nivel_minimo=0
nivel_maximo=60
Total_Atipicos=((Datos['free sulfur dioxide']<nivel_minimo)|(Datos['free sulfur dioxide']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 4

# %%
# Filtra Datos Atípicos

Datos=Datos[(Datos['free sulfur dioxide']<nivel_maximo)&(Datos['free sulfur dioxide']>nivel_minimo)]

# %%
# Validar si se removieron los datos atípicos

Total_Atipicos=((Datos['free sulfur dioxide']<nivel_minimo)|(Datos['free sulfur dioxide']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 0

# %%
#Conteo de Datos Atípicos
nivel_minimo=0
nivel_maximo=200
Total_Atipicos=((Datos['total sulfur dioxide']<nivel_minimo)|(Datos['total sulfur dioxide']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 0

# %%
# Filtra Datos Atípicos

Datos=Datos[(Datos['total sulfur dioxide']<nivel_maximo)&(Datos['total sulfur dioxide']>nivel_minimo)]

# %%
# Validar si se removieron los datos atípicos

Total_Atipicos=((Datos['total sulfur dioxide']<nivel_minimo)|(Datos['total sulfur dioxide']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 0

# %%
#Revisión del tipo de datos y datos faltantes

Datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1597 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1597 non-null   float64
#  1   volatile acidity      1597 non-null   float64
#  2   citric acid           1597 non-null   float64
#  3   residual sugar        1597 non-null   float64
#  4   chlorides             1597 non-null   float64
#  5   free sulfur dioxide   1597 non-null   float64
#  6   total sulfur dioxide  1597 non-null   float64
#  7   density               1597 non-null   float64
#  8   pH                    1597 non-null   float64
#  9   sulphates             1597 non-null   float64
#  10  alcohol               1597 non-null   float64
#  11  quality               1597 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 162.2 KB

# %% [raw]
# 2.Preprocesar los datos limpiándolos, tratando valores faltantes y transformándolos según sea necesario.
# Con el analisis realizado se opto que no hacia falta ningun dato ya que los datos donde se hayaban en 0 puede ser normal en con el tratamiento del vino

# %% [raw]
# 3.Seleccionar las características más relevantes para entrenar el modelo utilizando selección de características

# %%
# Total de calidades

Datos['quality'].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    197
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
# Total de alcohol

Datos['alcohol'].value_counts()
# Out:
# alcohol
# 9.500000     139
# 9.400000     103
# 9.800000      78
# 9.200000      72
# 10.000000     67
#             ...
# 9.950000       1
# 9.233333       1
# 9.250000       1
# 9.050000       1
# 10.750000      1
# Name: count, Length: 65, dtype: int64

# %% [raw]
# 4. Dividir el dataset en Train y Test para evaluar correctamente el modelo.

# %%
# Porcentaje de datos para entrenamiento (train) = 75% , y para prueba (test) = 25%

# Se crean variables X y Y para almacenar la información del entrenamiento

X = Datos.drop('quality',axis=1) # Se cargan los datos de train sin los datos de la columna quality
Y = Datos['quality'] # Se cargan los datos de train con los datos de la la columna Diabetico

#La función train_test_split crea una división de un conjunto de datos en dos bloques uno de entrenamiento y otro de prueba (train and test)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, stratify=Y, random_state= 0)

# %%
print (X_train)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 607             8.8             0.480         0.41             3.3      0.092
# 987             7.1             0.360         0.30             1.6      0.080
# 728             6.4             0.570         0.02             1.8      0.067
# 776             6.9             0.765         0.18             2.4      0.243
# 1147           10.0             0.410         0.45             6.2      0.071
# ...             ...               ...          ...             ...        ...
# 233             6.9             0.520         0.25             2.6      0.081
# 412             7.1             0.735         0.16             1.9      0.100
# 772             9.5             0.570         0.27             2.3      0.082
# 829             5.9             0.610         0.08             2.1      0.071
# 1526            6.8             0.470         0.08             2.2      0.064
#
# ...

# %%
print (Y_train)
# Out:
# 51      6
# 987     5
# 1278    6
# 208     5
# 944     7
#        ..
# 316     5
# 233     5
# 412     5
# 772     5
# 702     6
# Name: quality, Length: 1199, dtype: int64

# %% [raw]
# 5. Entrenar el modelo configurando los diferentes hiperparámetros.

# %%
# Crear el modelo de árbol de decisión con diferentes hiperparámetros
modelo_arbol = DecisionTreeClassifier(max_depth=5, min_samples_split=2, random_state=42)  # Puedes ajustar estos hiperparámetros según tus necesidades

# Entrenar el modelo
modelo_arbol.fit(X_train, Y_train)

# Realizar predicciones en el conjunto de prueba
predicciones = modelo_arbol.predict(X_test)

# %%
print (Y_test)
# Out:
# 499     6
# 683     5
# 840     7
# 1335    6
# 1148    6
#        ..
# 414     5
# 1035    7
# 1002    7
# 1020    6
# 735     5
# Name: quality, Length: 400, dtype: int64

# %%
print (predicciones)
# Out:
# [7 5 7 6 6 7 5 7 7 6 5 5 5 5 5 5 6 5 5 6 5 5 7 5 6 5 6 7 5 6 5 5 7 5 5 6 6
interpretar, analizar y documentar los resultados obtenidos

# %% [markdown]
# Para empezar, lo que se realizó fue cargar las librerías necesarias que nos permitirían manipular el archivo con la finalidad de que sea más manipulable en ese mismo paso realizamos el importe de las librerías par los modelos de ciencia de datos con el fin de poder aplicarles las métricas del modelo arboles de decisión y poder graficarlas.
# Luego pudimos realizar el cargo del archivo con el cual vamos a trabar y le dimos la lectura de los primeros 10 datos con el fin de entender la información del archivo a trabajar, una vez aquí le ejecutaremos una secuencia la cual nos permitirá obtener las medidas de tendencia central y medidas de dispersión
# Lo siguiente que se realizo fue la identificación de datos faltantes y valores atípicos, para los valores faltantes para mi criterio no se tuvo la necesidad de darle un valor ya que para la fabricación del vino un 0 puede suceder por diversos factores lo que puede ser común asi que se descarto la idea de quitar los valores faltantes o los 0, para los valores atípicos primero se realizaron unos diagramas de cajas para poder ver que valores pueden ser atípicos en mi caso no toque los valores que se basaban en unidades por ejemplo que no superaban el 2 como el caso de la Volatile Acidity ya que su mayor dato fue de 1.6 cosa que no se me hizo tan anormal y así con las diferentes variables, de las 12 variables escogi 5 que presentaban datos un poco anormales para mi análisis y se le realizaron la filtración de dichos valores atípicos, las variables que se les realizo fueron fixed acidity, volatile acidity, residual sugar, free sulfur dioxide, total sulfur dioxide. Terminado la filtración de los valores se realizó la verificación de los valores atípicos
# Para el desarrollo del 3 punto elegí como características importantes la calidad ya que pues es la que depende de cada uno de las 11 características para que de una buena calidad y como opcional elegi el alcohol, una ves elegido se realizo el conteo de los valores de las características seleccionadas.
# Luego, se dividió el dataset en train y test con el fin de poder evaluar el modelo, en este caso se opto por un 75% el train y un 25 el test, separando la quality para poder realizar el ejercicio y poder predecir sus valores.
# Una vez completa la partición realizaremos la configuración de nuestro modelo de árbol de decisión con los diferentes hiperparámetros, una vez entrenado se realizó la predicción de los valores con los que haremos la comparación, con la evaluar el desempeño del modelo en el conjunto de Test con métricas como precisión, recall, F1-score, etc. Podemos verificar las precisiones de las instancias clasificadas sean realmente de la cualidad de la predicción con esto se obtuvieron lo siguientes resultados, las calidades de 3 y 4 se pudo evidenciar muy bien en la predicción, la precisión disminuye casi un 40% entre el 5 y 6, un 60% en el 7 y por ultimo una disminución del 100% al tratar de predecir la cualidad 8, pero no solo nos basaremos en la precisión aplicaremos el recall aquí podemos tener una mayor comprensión, el recall es la proporción de instancias correctamente clasificadas como positivas sobre el total de instancias que realmente son positivas y nos arroja lo siguiente para la calidad 3 y 4 tenemos un 0, lo que indica que el modelo no pudo identificar correctamente ninguna de las instancias positivas, para la 5 se obtuvo 84% de predicción, para la 6 obtuvo un 47% de predicción, para el 7 un 46% de predicción y por ultimo nuevamente un 0 para el 8. Con esta información podemos deducir que el modelo de predicción tiene una efectividad de un 34% por el análisis del recall.
# Por último, podemos verificar la información con las graficas que se realizaron en este caso se usaron 3, el árbol de decisión que nos permite ver una parte de la información que llevo a las diferentes calidades del vino, por otra parte, tenemos la matriz de Confusión que nos proporciona información valiosa sobre los tipos de errores que comete el modelo, como falsos positivos, falsos negativos, verdaderos positivos y verdaderos negativos. Las filas representan las clases reales y las columnas representan las clases predichas por el modelo. Cada celda de la matriz contiene el número de instancias que pertenecen a una clase específica según la predicción del modelo. Y por último, se realizó la gráfica de la importancia de las características lo que nos muestra según el modelo que características son mas importantes sin contar la que se dividió. Y así terminamos el modelo de árbol de decisiones.
